# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=3)

# %% [markdown]
# MULTILINEARREGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
param_grid = {
    'fit_intercept': [True, False],  # Whether to calculate the intercept
    'copy_X': [True, False],         # Whether to copy X before fitting
    'n_jobs': [None, -1],            # Number of jobs to use for computation
    'positive': [True, False] 
}

# Initialize GridSearchCV
grid= GridSearchCV(LinearRegression(),param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', verbose=3)
   
# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-34644774.542 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-34644774.542 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-34644774.542 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-34644774.542 total time=   0.0s
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None, -1],
#                          'positive': [True, False]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100} is: 0.8184
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004720      0.004456         0.000000        0.000000
# 1        0.001826      0.000417         0.000000        0.000000
# 2        0.002109      0.000655         0.000000        0.000000
# 3        0.001528      0.001029         0.000000        0.000000
# 4        0.005424      0.006368         0.000000        0.000000
# 5        0.001839      0.000382         0.000000        0.000000
# 6        0.001903      0.000618         0.000000        0.000000
# 7        0.001372      0.000559         0.000000        0.000000
# 8        0.002208      0.000449         0.000000        0.000000
# 9        0.002405      0.000698         0.000000        0.000000
# 10       0.001660      0.000627         0.000000        0.000000
# 11       0.001826      0.000797         0.000000        0.000000
# 12       0.002538      0.001606         0.000000        0.000000
# 13       0.004128      0.005728         0.000000        0.000000
# 14       0.040806      0.004931         0.004543        0.003442
# 15       0.452122      0.109148         0.016943        0.003784
# 16       0.039709      0.007213         0.003900        0.002615
# 17       0.505470      0.136923         0.019323        0.003388
# 18       0.000386      0.000772         0.000000        0.000000
# 19       0.001620      0.002768         0.000000        0.000000
# 20       0.116918      0.016850         0.003030        0.001622
# 21       1.054954      0.145546         0.016732        0.006418
# 22       0.093401      0.019382         0.006281        0.001513
# 23       0.815236      0.338829         0.011250        0.004540
# 24       0.003476      0.003107         0.000000        0.000000
# 25       0.003371      0.003022         0.000000        0.000000
# 26       0.078803      0.015046         0.008940        0.005856
# 27       0.451396      0.079482         0.023929        0.015051
# 28       0.038061      0.006374         0.004401        0.001309
# 29       0.378988      0.041872         0.015638        0.003136
# 30       0.000688      0.000569         0.000000        0.000000
# 31       0.001296      0.001262         0.000000        0.000000
# 32       0.052538      0.008731         0.007979        0.008223
# 33       0.439917      0.040143         0.015445        0.004940
# 34       0.055578      0.013499         0.003384        0.001440
# 35       0.405191      0.037039         0.018245        0.005651
#
#    param_criterion param_max_features  param_n_estimators  \
# 0              mse               auto                  10
# 1              mse               auto                 100
# 2              mse               sqrt                  10
# 3              mse               sqrt                 100
# 4              mse               log2                  10
# 5              mse               log2                 100
# 6              mae               auto                  10
# 7              mae               auto                 100
# 8              mae               sqrt                  10
# 9              mae               sqrt                 100
# 10             mae               log2                  10
# 11             mae               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18  absolute_error               auto                  10
# 19  absolute_error               auto                 100
# 20  absolute_error               sqrt                  10
# 21  absolute_error               sqrt                 100
# 22  absolute_error               log2                  10
# 23  absolute_error               log2                 100
# 24   squared_error               auto                  10
# 25   squared_error               auto                 100
# 26   squared_error               sqrt                  10
# 27   squared_error               sqrt                 100
# 28   squared_error               log2                  10
# 29   squared_error               log2                 100
# 30         poisson               auto                  10
# 31         poisson               auto                 100
# 32         poisson               sqrt                  10
# 33         poisson               sqrt                 100
# 34         poisson               log2                  10
# 35         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 1   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 4   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 5   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 6   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 7   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 10  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 11  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.850214
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.855299
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.843822
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.859641
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...           0.843914
# 21  {'criterion': 'absolute_error', 'max_features'...           0.856222
# 22  {'criterion': 'absolute_error', 'max_features'...           0.841722
# 23  {'criterion': 'absolute_error', 'max_features'...           0.859938
# 24  {'criterion': 'squared_error', 'max_features':...                NaN
# 25  {'criterion': 'squared_error', 'max_features':...                NaN
# 26  {'criterion': 'squared_error', 'max_features':...           0.843936
# 27  {'criterion': 'squared_error', 'max_features':...           0.856462
# 28  {'criterion': 'squared_error', 'max_features':...           0.847931
# 29  {'criterion': 'squared_error', 'max_features':...           0.855838
# 30  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 31  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839743
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857831
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.837590
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.857811
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.772922           0.834456           0.799449
# 15           0.782296           0.844787           0.829615
# 16           0.771587           0.817069           0.815225
# 17           0.779823           0.846550           0.830129
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.799983           0.832785           0.790118
# 21           0.785181           0.847816           0.825279
# 22           0.783278           0.829352           0.797379
# 23           0.778202           0.845859           0.828759
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.731847           0.815908           0.809027
# 27           0.782662           0.847180           0.828530
# 28           0.779848           0.813916           0.808276
# 29           0.785388           0.844212           0.821757
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32           0.778147           0.831528           0.813537
# 33           0.784114           0.846013           0.827089
# 34           0.774277           0.820623           0.807850
# 35           0.783496           0.845218           0.826734
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2                 NaN              NaN             NaN               17
# 3                 NaN              NaN             NaN               17
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8                 NaN              NaN             NaN               17
# 9                 NaN              NaN             NaN               17
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.747036         0.800815        0.038063               12
# 15           0.765219         0.815443        0.035416                7
# 16           0.707440         0.791029        0.047782               15
# 17           0.775864         0.818402        0.034433                1
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.754902         0.804340        0.031751                9
# 21           0.777144         0.818329        0.032090                2
# 22           0.744789         0.799304        0.034452               13
# 23           0.764679         0.815487        0.037540                6
# 24                NaN              NaN             NaN               17
# 25                NaN              NaN             NaN               17
# 26           0.738586         0.787861        0.044597               16
# 27           0.771709         0.817309        0.034150                4
# 28           0.760461         0.802086        0.030024               10
# 29           0.769761         0.815391        0.033134                8
# 30                NaN              NaN             NaN               17
# 31                NaN              NaN             NaN               17
# 32           0.746103         0.801812        0.034994               11
# 33           0.770015         0.817012        0.034350                5
# 34           0.746776         0.797423        0.032745               14
# 35           0.777649         0.818182        0.032313                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))

# %% [markdown]
# SVR_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','sigmoid','linear'],
              'C':[10,100],'gamma':['auto','scale']} 


grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(x_train, y_train) #x_trian,y_train
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))
table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'C': 100, 'gamma': 'auto', 'kernel': 'linear'} is: 0.4953
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.081929      0.008745         0.042060        0.006863       10
# 1        0.039598      0.016176         0.006501        0.006451       10
# 2        0.061708      0.005100         0.006905        0.003778       10
# 3        0.056265      0.005409         0.037637        0.007614       10
# 4        0.070464      0.016300         0.011041        0.003439       10
# 5        0.044717      0.005468         0.008166        0.001669       10
# 6        0.068477      0.017986         0.041744        0.017301      100
# 7        0.046770      0.030115         0.008371        0.003084      100
# 8        0.144626      0.045010         0.005994        0.003320      100
# 9        0.063222      0.021550         0.033956        0.014410      100
# 10       0.077078      0.013281         0.014545        0.006602      100
# 11       0.109570      0.016686         0.004800        0.001263      100
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.099042
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.099095
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.016024
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.096770
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.100524
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.016024
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.094692
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.099095
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.510451
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.115168
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.118919
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.510451
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.166508          -0.089199          -0.167970
# 1           -0.164239          -0.089966          -0.168825
# 2           -0.128587          -0.031176          -0.101928
# 3           -0.165021          -0.083512          -0.168946
# 4           -0.164880          -0.091599          -0.173399
# 5           -0.128587          -0.031176          -0.101928
# 6           -0.162307          -0.080828          -0.163804
# 7           -0.164239          -0.089966          -0.168825
# 8            0.441085           0.501962           0.489229
# 9           -0.216231          -0.121982          -0.206347
# 10          -0.190041          -0.120151          -0.203936
# 11           0.441085           0.501962           0.489229
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.033239        -0.111192        0.050974                7
# 1           -0.035160        -0.111457        0.050026                8
# 2            0.037057        -0.048132        0.059904                3
# 3           -0.020501        -0.106950        0.055393                6
# 4           -0.036243        -0.113329        0.050684               10
# 5            0.037057        -0.048132        0.059904                3
# 6           -0.017104        -0.103747        0.055046                5
# 7           -0.035160        -0.111457        0.050026                8
# 8            0.533662         0.495278        0.030730                1
# 9           -0.047824        -0.141510        0.062673               12
# 10          -0.059531        -0.138516        0.052715               11
# 11           0.533662         0.495278        0.030730                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))

# %% [markdown]
# DECISION_TREE_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'max_depth': [None, 10, 20, 30],  # Use max_depth instead of max_features
    'min_samples_split': [2, 10, 20]} 
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 240 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 89 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 151 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.61064488 0.75325806 0.72710232
#  0.60817892 0.68859702 0.70490698        nan        nan        nan
#  0.62735497 0.74653275 0.77276348 0.62575355 0.74594894 0.71442524
#         nan        nan        nan 0.60399692 0.71441167 0.73275073
#  0.51409501 0.65301269 0.71440079        nan        nan        nan
#  0.63724486 0.71866401 0.7658453  0.55645741 0.78504739 0.75935029
#         nan        nan        nan 0.62730763 0.7695901  0.72709654
#  0.66577272 0.67348883 0.79238663        nan        nan        nan
#  0.68410853 0.67647432 0.7708322  0.7398526  0.76367671 0.72273659
#         nan        nan        nan 0.64999673 0.78417958 0.7942638
#  0.58316818 0.72269397 0.7814657         nan        nan        nan
#  0.6905924  0.74379377 0.77873916 0.65223803 0.73706618 0.71047247
#         nan        nan        nan 0.64532508 0.73325532 0.62529897
#  0.58557522 0.70948862 0.67121636        nan        nan        nan
#  0.67370547 0.72140489 0.76443981 0.65611514 0.74676375 0.66710812
#         nan        nan        nan 0.58310268 0.68941191 0.70893615
#  0.6816654  0.69440714 0.74996235        nan        nan        nan
#  0.56180977 0.69209302 0.74470169 0.62698647 0.677288   0.7067956
#         nan        nan        nan 0.63689498 0.69987705 0.74728088
#  0.65845942 0.71939885 0.74061006        nan        nan        nan
#  0.68148677 0.68861103 0.75477111 0.65794189 0.71185725 0.73133648
#         nan        nan        nan 0.57595401 0.68121648 0.73323706
#  0.59756974 0.77915844 0.62498657        nan        nan        nan
#  0.59146375 0.76249429 0.7145821  0.62875052 0.70754833 0.74735422]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'absolute_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 20} is: 0.7943
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.002042      0.000714         0.000000        0.000000
# 1         0.002785      0.001020         0.000000        0.000000
# 2         0.002376      0.001279         0.000000        0.000000
# 3         0.024999      0.015674         0.005600        0.003162
# 4         0.004866      0.000819         0.003359        0.000727
# ..             ...           ...              ...             ...
# 139       0.003852      0.003054         0.004909        0.003414
# 140       0.004977      0.002623         0.002979        0.002732
# 141       0.007665      0.002854         0.004441        0.003150
# 142       0.007175      0.001801         0.002708        0.000999
# 143       0.004679      0.002168         0.002140        0.000416
#
#     param_criterion param_max_depth param_max_features  \
# 0      friedman_mse            None               auto
# 1      friedman_mse            None               auto
# 2      friedman_mse            None               auto
# 3      friedman_mse            None               sqrt
# 4      friedman_mse            None               sqrt
# ..              ...             ...                ...
# 139         poisson              30               sqrt
# 140         poisson              30               sqrt
# 141         poisson              30               log2
# 142         poisson              30               log2
# 143         poisson              30               log2
#
#      param_min_samples_split  \
# 0                          2
# 1                         10
# 2                         20
# 3                          2
# 4                         10
# ..                       ...
# 139                       10
# 140                       20
# 141                        2
# 142                       10
# 143                       20
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'friedman_mse', 'max_depth': Non...                NaN
# 1    {'criterion': 'friedman_mse', 'max_depth': Non...                NaN
# 2    {'criterion': 'friedman_mse', 'max_depth': Non...                NaN
# 3    {'criterion': 'friedman_mse', 'max_depth': Non...           0.683139
# 4    {'criterion': 'friedman_mse', 'max_depth': Non...           0.789895
# ..                                                 ...                ...
# 139  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.851737
# 140  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.805551
# 141  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.711354
# 142  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.811915
# 143  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.851517
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3             0.631294           0.690160           0.543851
# 4             0.749055           0.771487           0.802649
# ..                 ...                ...                ...
# 139           0.732253           0.816780           0.742951
# 140           0.588717           0.790016           0.723346
# 141           0.581158           0.693459           0.695815
# 142           0.714879           0.658428           0.757678
# 143           0.618507           0.824707           0.755150
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                  NaN              NaN             NaN               97
# 1                  NaN              NaN             NaN               97
# 2                  NaN              NaN             NaN               97
# 3             0.504781         0.610645        0.074395               85
# 4             0.653204         0.753258        0.053184               17
# ..                 ...              ...             ...              ...
# 139           0.668751         0.762494        0.064800               14
# 140           0.665280         0.714582        0.080393               40
# 141           0.461967         0.628751        0.095488               78
# 142           0.594843         0.707548        0.075597               48
# 143           0.686889         0.747354        0.086200               19
#
# [144 rows x 17 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))

# %% [markdown]
# RANDOM_FOREST_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['mse','mae','friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]} 

grid=GridSearchCV(RandomForestRegressor(),param_grid,refit = True, verbose = 3,n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 100 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'friedman_mse', 'squared_error', 'absolute_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'absolute_error', 'friedman_mse', 'poisson'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'friedman_mse', 'poisson'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'poisson', 'squared_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'poisson', 'absolute_error', 'friedman_mse'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'friedman_mse', 'absolute_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'poisson', 'absolute_error', 'friedman_mse'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'friedman_mse', 'poisson'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'absolute_error', 'friedman_mse', 'poisson'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.79607052 0.81834538 0.80132903 0.81369095
#         nan        nan 0.8062414  0.81570022 0.79473128 0.8157895
#         nan        nan 0.79988113 0.81441664 0.80252902 0.81659462
#         nan        nan 0.79109396 0.81733717 0.79890857 0.81521161]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse',
#                                        'absolute_error', 'squared_error',
#                                        'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100} is: 0.8183
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001718      0.000963         0.000000        0.000000
# 1        0.002763      0.001011         0.000000        0.000000
# 2        0.002150      0.000734         0.000000        0.000000
# 3        0.002211      0.000688         0.000000        0.000000
# 4        0.002328      0.001749         0.000000        0.000000
# 5        0.001982      0.000668         0.000000        0.000000
# 6        0.001565      0.000485         0.000000        0.000000
# 7        0.001530      0.000441         0.000000        0.000000
# 8        0.001199      0.000399         0.000000        0.000000
# 9        0.001686      0.000406         0.000000        0.000000
# 10       0.000799      0.000747         0.000000        0.000000
# 11       0.002461      0.001796         0.000000        0.000000
# 12       0.002240      0.000803         0.000000        0.000000
# 13       0.001349      0.000475         0.000000        0.000000
# 14       0.043744      0.005080         0.005132        0.001467
# 15       0.421418      0.045106         0.020253        0.007755
# 16       0.045024      0.007275         0.005363        0.004844
# 17       0.447585      0.070700         0.033616        0.022283
# 18       0.005544      0.004396         0.000000        0.000000
# 19       0.001266      0.000512         0.000000        0.000000
# 20       0.128521      0.007540         0.004075        0.003824
# 21       1.171442      0.202448         0.017015        0.004479
# 22       0.126342      0.016817         0.007329        0.003390
# 23       0.839732      0.291894         0.012325        0.001924
# 24       0.002343      0.002324         0.000000        0.000000
# 25       0.003171      0.001430         0.000000        0.000000
# 26       0.066976      0.016356         0.002631        0.003602
# 27       0.456859      0.049662         0.018602        0.002257
# 28       0.046519      0.007395         0.005535        0.003277
# 29       0.403006      0.039924         0.017774        0.003237
# 30       0.002154      0.002514         0.000000        0.000000
# 31       0.001599      0.002750         0.000000        0.000000
# 32       0.051248      0.005553         0.004257        0.002755
# 33       0.492515      0.045002         0.022022        0.009952
# 34       0.052469      0.000898         0.005226        0.003667
# 35       0.442564      0.079322         0.014471        0.007150
#
#    param_criterion param_max_features  param_n_estimators  \
# 0              mse               auto                  10
# 1              mse               auto                 100
# 2              mse               sqrt                  10
# 3              mse               sqrt                 100
# 4              mse               log2                  10
# 5              mse               log2                 100
# 6              mae               auto                  10
# 7              mae               auto                 100
# 8              mae               sqrt                  10
# 9              mae               sqrt                 100
# 10             mae               log2                  10
# 11             mae               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18  absolute_error               auto                  10
# 19  absolute_error               auto                 100
# 20  absolute_error               sqrt                  10
# 21  absolute_error               sqrt                 100
# 22  absolute_error               log2                  10
# 23  absolute_error               log2                 100
# 24   squared_error               auto                  10
# 25   squared_error               auto                 100
# 26   squared_error               sqrt                  10
# 27   squared_error               sqrt                 100
# 28   squared_error               log2                  10
# 29   squared_error               log2                 100
# 30         poisson               auto                  10
# 31         poisson               auto                 100
# 32         poisson               sqrt                  10
# 33         poisson               sqrt                 100
# 34         poisson               log2                  10
# 35         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 1   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 4   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 5   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 6   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 7   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 10  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 11  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.845527
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.858914
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.850096
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.858412
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...           0.843347
# 21  {'criterion': 'absolute_error', 'max_features'...           0.850878
# 22  {'criterion': 'absolute_error', 'max_features'...           0.815050
# 23  {'criterion': 'absolute_error', 'max_features'...           0.858932
# 24  {'criterion': 'squared_error', 'max_features':...                NaN
# 25  {'criterion': 'squared_error', 'max_features':...                NaN
# 26  {'criterion': 'squared_error', 'max_features':...           0.839577
# 27  {'criterion': 'squared_error', 'max_features':...           0.850690
# 28  {'criterion': 'squared_error', 'max_features':...           0.830228
# 29  {'criterion': 'squared_error', 'max_features':...           0.854253
# 30  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 31  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.838849
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858717
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.843691
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.855691
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.764525           0.818422           0.802278
# 15           0.789180           0.845970           0.827127
# 16           0.763794           0.818274           0.818449
# 17           0.780104           0.842635           0.823193
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.775037           0.844084           0.820030
# 21           0.777604           0.846850           0.823520
# 22           0.804434           0.828164           0.802568
# 23           0.775890           0.845932           0.826186
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.772993           0.830588           0.811272
# 27           0.784591           0.844379           0.826975
# 28           0.794983           0.841779           0.807842
# 29           0.785214           0.845115           0.831906
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32           0.763227           0.814660           0.799821
# 33           0.782391           0.843917           0.832535
# 34           0.784464           0.821182           0.796854
# 35           0.778980           0.844035           0.829025
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2                 NaN              NaN             NaN               17
# 3                 NaN              NaN             NaN               17
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8                 NaN              NaN             NaN               17
# 9                 NaN              NaN             NaN               17
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.749601         0.796071        0.035039               14
# 15           0.770536         0.818345        0.033533                1
# 16           0.756033         0.801329        0.035830               11
# 17           0.764112         0.813691        0.036095                8
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.748708         0.806241        0.038165                9
# 21           0.779649         0.815700        0.031686                5
# 22           0.723441         0.794731        0.036793               15
# 23           0.772008         0.815789        0.035740                4
# 24                NaN              NaN             NaN               17
# 25                NaN              NaN             NaN               17
# 26           0.744975         0.799881        0.035738               12
# 27           0.765448         0.814417        0.033641                7
# 28           0.737814         0.802529        0.036280               10
# 29           0.766486         0.816595        0.034530                3
# 30                NaN              NaN             NaN               17
# 31                NaN              NaN             NaN               17
# 32           0.738913         0.791094        0.035809               16
# 33           0.769126         0.817337        0.035200                2
# 34           0.748352         0.798909        0.032466               13
# 35           0.768326         0.815212        0.035132                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
import pickle
filename="finalized_grid_RF_with_T&T.sav"
pickle.dump(grid, open(filename, 'wb'))

Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))

loaded_model = pickle.load(open("finalized_grid_RF_with_T&T.sav", 'rb'))
# Out:
# Future_Prediction=[43954.4243506]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
