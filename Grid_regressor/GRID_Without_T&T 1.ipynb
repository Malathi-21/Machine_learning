# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %% [markdown]
# MULTILINEARREGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
param_grid = {
    'fit_intercept': [True, False],  # Whether to calculate the intercept
    'copy_X': [True, False],         # Whether to copy X before fitting
    'n_jobs': [None, -1],            # Number of jobs to use for computation
    'positive': [True, False] 
}

# Initialize GridSearchCV
grid= GridSearchCV(LinearRegression(),param_grid=param_grid, cv=5, scoring='r2', verbose=3)
   
# fitting the model for grid search 
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.761 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.709 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.776 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.731 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.757 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=0.761 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=0.709 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=0.776 total time=   0.0s
# ...

# %%
y_pred=grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.749694530346479

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True} is: 0.7468
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005015      0.008099         0.005155        0.006550
# 1        0.007220      0.006537         0.002884        0.004036
# 2        0.004803      0.002747         0.001384        0.002077
# 3        0.005876      0.006415         0.000803        0.000984
# 4        0.005925      0.005190         0.000599        0.000797
# 5        0.002719      0.003331         0.003793        0.003093
# 6        0.000398      0.000488         0.005587        0.006849
# 7        0.004402      0.002993         0.001549        0.001297
# 8        0.002294      0.001339         0.002175        0.001530
# 9        0.003828      0.003542         0.000638        0.000526
# 10       0.002459      0.001882         0.001713        0.002539
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19118.8546002]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %% [markdown]
# SVR_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','sigmoid','linear'],
              'C':[10,100],'gamma':['auto','scale']} 


grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(indep, dep) #x_trian,y_train
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
y_pred=grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.5483146013160243

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))
table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'C': 100, 'gamma': 'auto', 'kernel': 'linear'} is: 0.5352
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.206311      0.042697         0.101930        0.032019       10
# 1        0.110643      0.027206         0.021782        0.015539       10
# 2        0.145119      0.019216         0.015287        0.005895       10
# 3        0.154839      0.039866         0.069416        0.017089       10
# 4        0.139850      0.017157         0.029220        0.011258       10
# 5        0.160700      0.045070         0.011352        0.001320       10
# 6        0.205202      0.095357         0.091397        0.034910      100
# 7        0.128412      0.059105         0.021588        0.005723      100
# 8        0.428942      0.088519         0.016061        0.009282      100
# 9        0.151797      0.027494         0.089633        0.034080      100
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[11091.31878225]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %% [markdown]
# DECISION_TREE_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': [None,'sqrt','log2'],
              'max_depth': [None, 10, 20, 30],  # Use max_depth instead of max_features
    'min_samples_split': [2, 10, 20]} 
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=3)

# %%
y_pred=grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.8885727932901533

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'poisson', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 20} is: 0.8144
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.002131      0.000690         0.000000        0.000000
# 1         0.003309      0.001281         0.000000        0.000000
# 2         0.008471      0.011104         0.000000        0.000000
# 3         0.014928      0.013124         0.003618        0.000527
# 4         0.007256      0.003530         0.003735        0.001591
# ..             ...           ...              ...             ...
# 139       0.008293      0.001975         0.003432        0.001581
# 140       0.007507      0.001567         0.002672        0.000444
# 141       0.010001      0.001426         0.002249        0.002210
# 142       0.008200      0.001825         0.003634        0.001851
# 143       0.009448      0.004757         0.002608        0.000491
#
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[5612.64860323]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# RANDOM_FOREST_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': [None,'sqrt','log2'],
              'n_estimators':[10,100]} 

grid=GridSearchCV(RandomForestRegressor(),param_grid,refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
y_pred=grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.9692512813134111

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100} is: 0.8344
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003383      0.001568         0.000000        0.000000
# 1        0.001727      0.000546         0.000000        0.000000
# 2        0.001957      0.000433         0.000000        0.000000
# 3        0.002979      0.002059         0.000000        0.000000
# 4        0.002320      0.000825         0.000000        0.000000
# 5        0.003201      0.001902         0.000000        0.000000
# 6        0.002940      0.001017         0.000000        0.000000
# 7        0.002575      0.000963         0.000000        0.000000
# 8        0.002421      0.000345         0.000000        0.000000
# 9        0.002397      0.001129         0.000000        0.000000
# 10       0.001748      0.000324         0.000000        0.000000
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
import pickle
filename="finalized_grid_RF_without_T&T.sav"
pickle.dump(grid, open(filename, 'wb'))

Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))

loaded_model = pickle.load(open("finalized_grid_RF_without_T&T.sav", 'rb'))
# Out:
# Future_Prediction=[9279.5457963]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
