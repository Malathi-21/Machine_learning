# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=df.iloc[:, [3,4]].values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import MeanShift
MS=MeanShift(bandwidth=2).fit(x)
y_ms=MS.predict(x)
y_ms
# Out:
# array([137, 136,  42,  43, 135,  43,  42, 134, 133, 132,  19, 131,  19,
#         41,  19,  41, 130, 129, 128, 127, 126,  40, 125,  40, 124, 122,
#         39, 123,  39, 121, 120, 119, 118, 115, 117, 116, 114, 113, 112,
#        111,  38, 110,  38, 108, 109, 107, 105, 106,  37,  37, 104,  36,
#        102,  36,  18, 103, 101,  18,   6,  18,  35,  35,   6,  17,   6,
#         17,   6,  16,  17,  16,  34, 100,  99,  34,  14,   2,   2,  14,
#          2,  33,   2,  13,  33,  15,  13,  14,  98,  32,  96,  97,  32,
#          5,   1,   5,   5,  11,   1,   1,   0,   1,   0,   4,  95,  12,
#         12,   0,   3,   4,  10,   4,  11,  12,  10,   4,   3,   3,  31,
#         94,  31,  30,  30,  93,  92,  91,  90,  89,  27,  88,  29,  28,
#         29,  28,  27,  87,   9,  86,   9,  26,  85,  26,   9,  84,  83,
#         82,  81,  79,  80,  25,  22,   8,  23,   8,  22,  21,  23,   8,
#         24,  21,  24,  25,  78,  77,  76,  75,  74,  20,  73,  72,  70,
# ...

# %%
plt.scatter(x[:, 0], x[:, 1], c=y_ms, cmap='viridis', marker='o', edgecolor='k', s=30)
plt.title("Mean Shift Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.colorbar(label="Cluster Label")
plt.show()

# %%
supervised=df
supervised['Cluster_values']=y_ms
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_values
# 0               137
# 1               136
# 2                42
# ...

# %%
supervised.to_csv("clustered_data.csv", index=False)

# %%
centroids=ms.cluster_centers_
centroids
# Out:
# array([[ 62.        ,  42.        ],
#        [ 60.6       ,  48.6       ],
#        [ 54.        ,  53.        ],
#        [ 64.        ,  49.        ],
#        [ 63.        ,  47.        ],
#        [ 60.        ,  41.25      ],
#        [ 47.25      ,  51.        ],
#        [ 87.66666667,  13.66666667],
#        [ 78.        ,  89.        ],
#        [ 73.66666667,   5.66666667],
#        [ 64.        ,  42.66666667],
#        [ 63.        ,  52.        ],
#        [ 62.33333333,  55.        ],
#        [ 54.        ,  55.33333333],
#        [ 54.        ,  47.        ],
#        [ 54.        ,  44.        ],
#        [ 48.        ,  48.33333333],
#        [ 47.66666667,  59.        ],
#        [ 44.33333333,  45.66666667],
#        [ 19.66666667,  14.        ],
#        [ 86.        ,  75.        ],
#        [ 78.        ,  77.        ],
#        [ 78.        ,  21.        ],
#        [ 78.        ,  16.5       ],
#        [ 78.        ,   1.        ],
# ...

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5],
                 fit_reg=False, legend=False,palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=supervised.iloc[:, 3], y=supervised.iloc[:, 4], hue=supervised['Cluster_values'], palette='viridis', s=100, edgecolor='k')
#plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='blue',marker='X', label='Centroids')
plt.title('MeanShift Clustering')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
