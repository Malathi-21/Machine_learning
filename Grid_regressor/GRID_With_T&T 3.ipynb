# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=3)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# MULTILINEARREGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
param_grid = {
    'fit_intercept': [True, False],  # Whether to calculate the intercept
    'copy_X': [True, False],         # Whether to copy X before fitting
    'n_jobs': [None, -1],            # Number of jobs to use for computation
    'positive': [True, False] 
}

# Initialize GridSearchCV
grid= GridSearchCV(LinearRegression(),param_grid=param_grid, scoring='neg_mean_squared_error', verbose=3)
   
# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-228369495.202 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-214381108.516 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-211930349.929 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-228418671.841 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-216085978.155 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-212556500.485 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-228369495.202 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-214381108.516 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-211930349.929 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-228418671.841 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-216085978.155 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-212556500.485 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-228369495.202 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-214381108.516 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-211930349.929 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-228418671.841 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-216085978.155 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-212556500.485 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-228369495.202 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-214381108.516 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-211930349.929 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-217785440.953 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-228418671.841 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-216085978.155 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-206714646.339 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-212556500.485 total time=   0.0s
# GridSearchCV(estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None, -1],
#                          'positive': [True, False]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.7426

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True} is: -36957195.1679
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006745      0.012018         0.000628        0.000841
# 1        0.002397      0.002980         0.000200        0.000399
# 2        0.000906      0.001166         0.000000        0.000000
# 3        0.001021      0.000750         0.001592        0.002712
# 4        0.001242      0.001394         0.000207        0.000414
# 5        0.001024      0.001127         0.000236        0.000433
# 6        0.001283      0.000784         0.001022        0.000664
# 7        0.000828      0.000776         0.000000        0.000000
# 8        0.002348      0.001495         0.000731        0.000418
# 9        0.000000      0.000000         0.000000        0.000000
# 10       0.002594      0.003735         0.000203        0.000407
# 11       0.000962      0.000899         0.001759        0.003230
# 12       0.000524      0.001047         0.000000        0.000000
# 13       0.000789      0.000426         0.000325        0.000415
# 14       0.000000      0.000000         0.000000        0.000000
# 15       0.002898      0.004168         0.000598        0.000488
#
#     param_copy_X  param_fit_intercept param_n_jobs  param_positive  \
# 0           True                 True         None            True
# 1           True                 True         None           False
# 2           True                 True           -1            True
# 3           True                 True           -1           False
# 4           True                False         None            True
# 5           True                False         None           False
# 6           True                False           -1            True
# 7           True                False           -1           False
# 8          False                 True         None            True
# 9          False                 True         None           False
# 10         False                 True           -1            True
# 11         False                 True           -1           False
# 12         False                False         None            True
# 13         False                False         None           False
# 14         False                False           -1            True
# 15         False                False           -1           False
#
#                                                params  split0_test_score  \
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 1   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 2   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 3   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 4   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -2.177854e+08
# 5   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -2.177854e+08
# 6   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -2.177854e+08
# 7   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -2.177854e+08
# 8   {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 9   {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 10  {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 11  {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 12  {'copy_X': False, 'fit_intercept': False, 'n_j...      -2.177854e+08
# 13  {'copy_X': False, 'fit_intercept': False, 'n_j...      -2.177854e+08
# 14  {'copy_X': False, 'fit_intercept': False, 'n_j...      -2.177854e+08
# 15  {'copy_X': False, 'fit_intercept': False, 'n_j...      -2.177854e+08
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.015673        -0.068262        0.053734               11
# 1            0.068267        -0.014551        0.053566                9
# 2            0.430670         0.356188        0.050029                5
# 3            0.015867        -0.068285        0.053901               12
# 4            0.067424        -0.014582        0.052996               10
# 5            0.430670         0.356188        0.050029                5
# 6            0.327775         0.224796        0.061506                7
# 7            0.529681         0.484472        0.035721                4
# 8            0.622740         0.599273        0.021435                1
# 9            0.329162         0.224749        0.062653                8
# 10           0.528560         0.484477        0.035410                3
# 11           0.622740         0.599273        0.021435                1

# %% [markdown]
# DECISION_TREE_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': [None,'sqrt','log2'],
              'max_depth': [None, 10, 20, 30],  # Use max_depth instead of max_features
    'min_samples_split': [2, 10, 20]} 
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.8430

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'absolute_error', 'max_depth': None, 'max_features': None, 'min_samples_split': 20} is: 0.8333
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.006060      0.001775         0.001397        0.000718
# 1         0.006606      0.002834         0.001572        0.001029
# 2         0.003908      0.000816         0.001936        0.001198
# 3         0.004008      0.001020         0.001778        0.000975
# 4         0.003612      0.001139         0.001957        0.000660
# ..             ...           ...              ...             ...
# 139       0.003142      0.000793         0.001817        0.001351
# 140       0.002249      0.002093         0.002020        0.001277
# 141       0.003651      0.002930         0.000805        0.000998
# 142       0.003247      0.003249         0.001684        0.002513
# 143       0.003699      0.002450         0.001411        0.000473
#
#     param_criterion param_max_depth param_max_features  \
# 0      friedman_mse            None               None
# 1      friedman_mse            None               None
# 2      friedman_mse            None               None
# 3      friedman_mse            None               sqrt
# 4      friedman_mse            None               sqrt
# ..              ...             ...                ...
# 139         poisson              30               sqrt
# 140         poisson              30               sqrt
# 141         poisson              30               log2
# 142         poisson              30               log2
# 143         poisson              30               log2
#
#      param_min_samples_split  \
# 0                          2
# 1                         10
# 2                         20
# 3                          2
# 4                         10
# ..                       ...
# 139                       10
# 140                       20
# 141                        2
# 142                       10
# 143                       20
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'friedman_mse', 'max_depth': Non...           0.749345
# 1    {'criterion': 'friedman_mse', 'max_depth': Non...           0.830607
# 2    {'criterion': 'friedman_mse', 'max_depth': Non...           0.838256
# 3    {'criterion': 'friedman_mse', 'max_depth': Non...           0.713563
# 4    {'criterion': 'friedman_mse', 'max_depth': Non...           0.818521
# ..                                                 ...                ...
# 139  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.831785
# 140  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.770631
# 141  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.606862
# 142  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.791562
# 143  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.864231
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.694135           0.807331           0.612379
# 1             0.735795           0.810764           0.772136
# 2             0.779906           0.813458           0.803787
# 3             0.695886           0.709853           0.580836
# 4             0.737714           0.772189           0.766612
# ..                 ...                ...                ...
# 139           0.755281           0.736619           0.711693
# 140           0.757557           0.813696           0.640490
# 141           0.665084           0.615539           0.717753
# 142           0.771175           0.508337           0.743425
# 143           0.789398           0.812695           0.668356
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.649411         0.702520        0.069562               83
# 1             0.738045         0.777469        0.038083               31
# 2             0.727432         0.792568        0.037557               16
# 3             0.483876         0.636803        0.090816              121
# 4             0.672246         0.753456        0.048167               49
# ..                 ...              ...             ...              ...
# 139           0.559383         0.718952        0.089306               71
# 140           0.753372         0.747149        0.057451               54
# 141           0.424042         0.605856        0.099177              130
# 142           0.720428         0.706985        0.102219               81
# 143           0.664257         0.759788        0.080088               42
#
# [144 rows x 17 columns]

# %% [markdown]
# RANDOM_FOREST_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': [None,'sqrt','log2'],
              'n_estimators':[10,100]} 

grid=GridSearchCV(RandomForestRegressor(),param_grid,refit = True, verbose = 3,n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.8509

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100} is: 0.8182
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.131257      0.082102         0.005019        0.001926
# 1        0.671262      0.115349         0.019510        0.013584
# 2        0.042414      0.013105         0.002669        0.002319
# 3        0.495046      0.107752         0.016223        0.006559
# 4        0.046028      0.003771         0.004692        0.000978
# 5        0.435625      0.061573         0.013393        0.003853
# 6        0.168089      0.024413         0.001021        0.000919
# 7        1.487375      0.180451         0.020659        0.010690
# 8        0.098121      0.005819         0.001912        0.002504
# 9        1.178848      0.146410         0.013196        0.004808
# 10       0.108315      0.029424         0.003358        0.003045
# 11       1.070925      0.136775         0.014055        0.002926
# 12       0.055837      0.009984         0.002714        0.001033
# 13       0.472006      0.041446         0.012066        0.001466
# 14       0.038130      0.003279         0.003672        0.004373
# 15       0.351266      0.029390         0.015564        0.003859
# 16       0.032299      0.003088         0.002465        0.003991
# 17       0.348000      0.016411         0.012845        0.003759
# 18       0.054923      0.003439         0.001711        0.001544
# 19       0.497974      0.035643         0.011564        0.002020
# 20       0.040426      0.000372         0.000399        0.000798
# 21       0.361486      0.009272         0.012519        0.003137
# 22       0.039603      0.002682         0.002667        0.001360
# 23       0.325155      0.014452         0.007799        0.001678
#
#    param_criterion param_max_features  param_n_estimators  \
# 0     friedman_mse               None                  10
# 1     friedman_mse               None                 100
# 2     friedman_mse               sqrt                  10
# 3     friedman_mse               sqrt                 100
# 4     friedman_mse               log2                  10
# 5     friedman_mse               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12   squared_error               None                  10
# 13   squared_error               None                 100
# 14   squared_error               sqrt                  10
# 15   squared_error               sqrt                 100
# 16   squared_error               log2                  10
# 17   squared_error               log2                 100
# 18         poisson               None                  10
# 19         poisson               None                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'max_features': ...           0.818975
# 1   {'criterion': 'friedman_mse', 'max_features': ...           0.850945
# 2   {'criterion': 'friedman_mse', 'max_features': ...           0.849675
# 3   {'criterion': 'friedman_mse', 'max_features': ...           0.853956
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.833146
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.851064
# 6   {'criterion': 'absolute_error', 'max_features'...           0.834679
# 7   {'criterion': 'absolute_error', 'max_features'...           0.844018
# 8   {'criterion': 'absolute_error', 'max_features'...           0.846730
# 9   {'criterion': 'absolute_error', 'max_features'...           0.859299
# 10  {'criterion': 'absolute_error', 'max_features'...           0.845583
# 11  {'criterion': 'absolute_error', 'max_features'...           0.854836
# 12  {'criterion': 'squared_error', 'max_features':...           0.851258
# 13  {'criterion': 'squared_error', 'max_features':...           0.848876
# 14  {'criterion': 'squared_error', 'max_features':...           0.833263
# 15  {'criterion': 'squared_error', 'max_features':...           0.852787
# 16  {'criterion': 'squared_error', 'max_features':...           0.845320
# 17  {'criterion': 'squared_error', 'max_features':...           0.856452
# 18  {'criterion': 'poisson', 'max_features': None,...           0.839968
# 19  {'criterion': 'poisson', 'max_features': None,...           0.849394
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839996
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.848631
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.839770
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.849109
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.793766           0.840860           0.790968
# 1            0.792502           0.846949           0.809682
# 2            0.769842           0.818328           0.828309
# 3            0.782767           0.842614           0.832060
# 4            0.795842           0.826408           0.816888
# 5            0.784176           0.839787           0.823753
# 6            0.784111           0.830441           0.770660
# 7            0.786502           0.845226           0.799904
# 8            0.765318           0.836011           0.806297
# 9            0.782709           0.846235           0.830435
# 10           0.785766           0.825535           0.807310
# 11           0.777625           0.839734           0.829140
# 12           0.794622           0.827535           0.804170
# 13           0.795796           0.849319           0.809731
# 14           0.744610           0.829778           0.796528
# 15           0.780737           0.845450           0.832060
# 16           0.774759           0.836179           0.804766
# 17           0.786595           0.839381           0.830013
# 18           0.788690           0.855286           0.795146
# 19           0.796689           0.846684           0.812979
# 20           0.772940           0.822828           0.803479
# 21           0.786461           0.845537           0.827918
# 22           0.784471           0.824239           0.810601
# 23           0.786494           0.844503           0.829103
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.750880         0.799090        0.030195               18
# 1            0.769002         0.813816        0.031483                9
# 2            0.745023         0.802236        0.038761               15
# 3            0.767445         0.815769        0.034260                4
# 4            0.703088         0.795074        0.047685               21
# 5            0.766243         0.813005        0.032555               11
# 6            0.741894         0.792357        0.035572               23
# 7            0.765592         0.808248        0.031651               13
# 8            0.724584         0.795788        0.045435               20
# 9            0.763231         0.816382        0.037120                3
# 10           0.734184         0.799675        0.038255               17
# 11           0.783039         0.816875        0.030982                2
# 12           0.770680         0.809653        0.027661               12
# 13           0.762397         0.813224        0.033085               10
# 14           0.741374         0.789111        0.039793               24
# 15           0.767201         0.815647        0.034936                5
# 16           0.725339         0.797272        0.043726               19
# 17           0.778790         0.818246        0.030343                1
# 18           0.745097         0.804838        0.039250               14
# 19           0.767826         0.814715        0.030826                8
# 20           0.735108         0.794870        0.037268               22
# 21           0.768664         0.815442        0.032221                6
# 22           0.744796         0.800775        0.033368               16
# 23           0.766066         0.815055        0.032984                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
import pickle
filename="finalized_grid_RF_with_T&T.sav"
pickle.dump(grid, open(filename, 'wb'))

Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))

loaded_model = pickle.load(open("finalized_grid_RF_with_T&T.sav", 'rb'))
# Out:
# Future_Prediction=[17734.3121567]
