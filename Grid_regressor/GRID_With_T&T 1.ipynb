# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=3)

# %% [markdown]
# MULTILINEARREGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
param_grid = {
    'fit_intercept': [True, False],  # Whether to calculate the intercept
    'copy_X': [True, False],         # Whether to copy X before fitting
    'n_jobs': [None, -1],            # Number of jobs to use for computation
    'positive': [True, False] 
}

# Initialize GridSearchCV
grid= GridSearchCV(LinearRegression(),param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', verbose=3)
   
# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=-1, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-34644774.542 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=-1, positive=False;, score=-34644774.542 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-47696004.783 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-30752456.419 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-37642430.971 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=True;, score=-32029117.219 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-36665966.448 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-47702812.091 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-30925036.713 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-37908738.666 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=-1, positive=False;, score=-32018039.486 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-34644774.542 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-42278285.028 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-54703863.118 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-36139801.541 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-41821736.137 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=True;, score=-34962537.683 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-41999812.592 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-54789622.352 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-36641030.714 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-42276376.456 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=-1, positive=False;, score=-34644774.542 total time=   0.0s
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None, -1],
#                          'positive': [True, False]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.7426

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True} is: -36957195.1679
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004560      0.000575         0.002327        0.000459
# 1        0.002023      0.001461         0.002325        0.001336
# 2        0.002854      0.001961         0.001167        0.001353
# 3        0.002282      0.002949         0.001357        0.001300
# 4        0.002897      0.001145         0.001001        0.000642
# 5        0.002544      0.001781         0.001230        0.000759
# 6        0.002766      0.001797         0.000841        0.000429
# 7        0.002184      0.000582         0.000916        0.000515
# 8        0.003068      0.001221         0.000999        0.000634
# 9        0.002962      0.001059         0.001526        0.000505
# 10       0.003307      0.002197         0.002374        0.000934
# 11       0.003227      0.000314         0.001782        0.000763
# 12       0.003518      0.001546         0.001125        0.000676
# 13       0.002642      0.001077         0.001695        0.000711
# 14       0.001809      0.001544         0.002247        0.003718
# 15       0.001989      0.000999         0.001666        0.001403
#
#     param_copy_X  param_fit_intercept param_n_jobs  param_positive  \
# 0           True                 True         None            True
# 1           True                 True         None           False
# 2           True                 True           -1            True
# 3           True                 True           -1           False
# 4           True                False         None            True
# 5           True                False         None           False
# 6           True                False           -1            True
# 7           True                False           -1           False
# 8          False                 True         None            True
# 9          False                 True         None           False
# 10         False                 True           -1            True
# 11         False                 True           -1           False
# 12         False                False         None            True
# 13         False                False         None           False
# 14         False                False           -1            True
# 15         False                False           -1           False
#
#                                                params  split0_test_score  \
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 1   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 2   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 3   {'copy_X': True, 'fit_intercept': True, 'n_job...      -3.666597e+07
# 4   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -4.227829e+07
# 5   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -4.199981e+07
# 6   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -4.227829e+07
# 7   {'copy_X': True, 'fit_intercept': False, 'n_jo...      -4.199981e+07
# 8   {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 9   {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 10  {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 11  {'copy_X': False, 'fit_intercept': True, 'n_jo...      -3.666597e+07
# 12  {'copy_X': False, 'fit_intercept': False, 'n_j...      -4.227829e+07
# 13  {'copy_X': False, 'fit_intercept': False, 'n_j...      -4.199981e+07
# 14  {'copy_X': False, 'fit_intercept': False, 'n_j...      -4.227829e+07
# 15  {'copy_X': False, 'fit_intercept': False, 'n_j...      -4.199981e+07
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0       -4.769600e+07      -3.075246e+07      -3.764243e+07
# 1       -4.770281e+07      -3.092504e+07      -3.790874e+07
# 2       -4.769600e+07      -3.075246e+07      -3.764243e+07
# 3       -4.770281e+07      -3.092504e+07      -3.790874e+07
# 4       -5.470386e+07      -3.613980e+07      -4.182174e+07
# 5       -5.478962e+07      -3.664103e+07      -4.227638e+07
# 6       -5.470386e+07      -3.613980e+07      -4.182174e+07
# 7       -5.478962e+07      -3.664103e+07      -4.227638e+07
# 8       -4.769600e+07      -3.075246e+07      -3.764243e+07
# 9       -4.770281e+07      -3.092504e+07      -3.790874e+07
# 10      -4.769600e+07      -3.075246e+07      -3.764243e+07
# 11      -4.770281e+07      -3.092504e+07      -3.790874e+07
# 12      -5.470386e+07      -3.613980e+07      -4.182174e+07
# 13      -5.478962e+07      -3.664103e+07      -4.227638e+07
# 14      -5.470386e+07      -3.613980e+07      -4.182174e+07
# 15      -5.478962e+07      -3.664103e+07      -4.227638e+07
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0       -3.202912e+07    -3.695720e+07    5.977644e+06                1
# 1       -3.201804e+07    -3.704412e+07    5.953200e+06                5
# 2       -3.202912e+07    -3.695720e+07    5.977644e+06                1
# 3       -3.201804e+07    -3.704412e+07    5.953200e+06                5
# 4       -3.496254e+07    -4.198124e+07    7.005190e+06                9
# 5       -3.464477e+07    -4.207032e+07    7.020598e+06               13
# 6       -3.496254e+07    -4.198124e+07    7.005190e+06                9
# 7       -3.464477e+07    -4.207032e+07    7.020598e+06               13
# 8       -3.202912e+07    -3.695720e+07    5.977644e+06                1
# 9       -3.201804e+07    -3.704412e+07    5.953200e+06                5
# 10      -3.202912e+07    -3.695720e+07    5.977644e+06                1
# 11      -3.201804e+07    -3.704412e+07    5.953200e+06                5
# 12      -3.496254e+07    -4.198124e+07    7.005190e+06                9
# 13      -3.464477e+07    -4.207032e+07    7.020598e+06               13
# 14      -3.496254e+07    -4.198124e+07    7.005190e+06                9
# 15      -3.464477e+07    -4.207032e+07    7.020598e+06               13

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[34739.82562812]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# SVR_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','sigmoid','linear'],
              'C':[10,100],'gamma':['auto','scale']} 


grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(x_train, y_train) #x_trian,y_train
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.5189

# %%
re=grid.cv_results_

print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))
table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'C': 100, 'gamma': 'auto', 'kernel': 'linear'} is: 0.4953
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.074009      0.022041         0.034402        0.008826       10
# 1        0.036761      0.008885         0.009038        0.007519       10
# 2        0.060064      0.006431         0.005899        0.001207       10
# 3        0.047943      0.010656         0.027287        0.002149       10
# 4        0.063923      0.013319         0.013107        0.003476       10
# 5        0.049627      0.004313         0.005422        0.001813       10
# 6        0.057935      0.016111         0.031703        0.008171      100
# 7        0.036759      0.007844         0.007751        0.001657      100
# 8        0.102865      0.009476         0.007020        0.004243      100
# 9        0.049838      0.004895         0.024672        0.004123      100
# 10       0.055322      0.007389         0.012743        0.001748      100
# 11       0.092939      0.006375         0.004523        0.001412      100
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.099042
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.099095
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.016024
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.096770
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.100524
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.016024
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.094692
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.099095
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.510451
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.115168
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.118919
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.510451
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.166508          -0.089199          -0.167970
# 1           -0.164239          -0.089966          -0.168825
# 2           -0.128587          -0.031176          -0.101928
# 3           -0.165021          -0.083512          -0.168946
# 4           -0.164880          -0.091599          -0.173399
# 5           -0.128587          -0.031176          -0.101928
# 6           -0.162307          -0.080828          -0.163804
# 7           -0.164239          -0.089966          -0.168825
# 8            0.441085           0.501962           0.489229
# 9           -0.216231          -0.121982          -0.206347
# 10          -0.190041          -0.120151          -0.203936
# 11           0.441085           0.501962           0.489229
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.033239        -0.111192        0.050974                7
# 1           -0.035160        -0.111457        0.050026                8
# 2            0.037057        -0.048132        0.059904                3
# 3           -0.020501        -0.106950        0.055393                6
# 4           -0.036243        -0.113329        0.050684               10
# 5            0.037057        -0.048132        0.059904                3
# 6           -0.017104        -0.103747        0.055046                5
# 7           -0.035160        -0.111457        0.050026                8
# 8            0.533662         0.495278        0.030730                1
# 9           -0.047824        -0.141510        0.062673               12
# 10          -0.059531        -0.138516        0.052715               11
# 11           0.533662         0.495278        0.030730                1

# %% [markdown]
# DECISION_TREE_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': [None,'sqrt','log2'],
              'max_depth': [None, 10, 20, 30],  # Use max_depth instead of max_features
    'min_samples_split': [2, 10, 20]} 
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.7374

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10} is: 0.7907
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.007850      0.006376         0.000000        0.000000
# 1         0.002004      0.000973         0.000000        0.000000
# 2         0.002165      0.000825         0.000000        0.000000
# 3         0.008255      0.000846         0.005755        0.001905
# 4         0.007373      0.001707         0.003825        0.000990
# ..             ...           ...              ...             ...
# 139       0.006111      0.002307         0.003665        0.001118
# 140       0.007184      0.002555         0.004808        0.004121
# 141       0.012204      0.005436         0.004149        0.001545
# 142       0.007687      0.000878         0.004293        0.001229
# 143       0.006598      0.003156         0.002667        0.000529
#
#     param_criterion param_max_depth param_max_features  \
# 0      friedman_mse            None               auto
# 1      friedman_mse            None               auto
# 2      friedman_mse            None               auto
# 3      friedman_mse            None               sqrt
# 4      friedman_mse            None               sqrt
# ..              ...             ...                ...
# 139         poisson              30               sqrt
# 140         poisson              30               sqrt
# 141         poisson              30               log2
# 142         poisson              30               log2
# 143         poisson              30               log2
#
#      param_min_samples_split  \
# 0                          2
# 1                         10
# 2                         20
# 3                          2
# 4                         10
# ..                       ...
# 139                       10
# 140                       20
# 141                        2
# 142                       10
# 143                       20
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'friedman_mse', 'max_depth': Non...                NaN
# 1    {'criterion': 'friedman_mse', 'max_depth': Non...                NaN
# 2    {'criterion': 'friedman_mse', 'max_depth': Non...                NaN
# 3    {'criterion': 'friedman_mse', 'max_depth': Non...           0.652218
# 4    {'criterion': 'friedman_mse', 'max_depth': Non...           0.817581
# ..                                                 ...                ...
# 139  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.834804
# 140  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.833368
# 141  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.745846
# 142  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.724266
# 143  {'criterion': 'poisson', 'max_depth': 30, 'max...           0.750238
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3             0.648593           0.764900           0.569666
# 4             0.735556           0.801324           0.629638
# ..                 ...                ...                ...
# 139           0.635462           0.815050           0.786652
# 140           0.584638           0.773709           0.808931
# 141           0.654451           0.703004           0.690850
# 142           0.738557           0.775522           0.746575
# 143           0.761587           0.671304           0.763622
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                  NaN              NaN             NaN               97
# 1                  NaN              NaN             NaN               97
# 2                  NaN              NaN             NaN               97
# 3             0.485472         0.624170        0.093162               79
# 4             0.699766         0.736773        0.068623               19
# ..                 ...              ...             ...              ...
# 139           0.497363         0.713866        0.128983               40
# 140           0.675902         0.735309        0.092457               20
# 141           0.674348         0.693700        0.030753               53
# 142           0.558661         0.708716        0.076870               43
# 143           0.715326         0.732415        0.035126               25
#
# [144 rows x 17 columns]

# %% [markdown]
# RANDOM_FOREST_GRID

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['friedman_mse','absolute_error','squared_error','poisson'],
              'max_features': [None,'sqrt','log2'],
              'n_estimators':[10,100]} 

grid=GridSearchCV(RandomForestRegressor(),param_grid,refit = True, verbose = 3,n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'squared_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
from sklearn.metrics import r2_score
y_pred = grid.predict(x_test)
r2_value = r2_score(y_test, y_pred)
print("The R² score value on the test data is: {:.4f}".format(r2_value))
# Out:
# The R² score value on the test data is: 0.8482

# %%
re=grid.cv_results_
print("The R² score value for the best parameters {} is: {:.4f}".format(grid.best_params_, grid.best_score_))

table=pd.DataFrame.from_dict(re)
table
# Out:
# The R² score value for the best parameters {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100} is: 0.8188
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001737  2.566831e-04         0.000000        0.000000
# 1        0.001708  8.981212e-04         0.000000        0.000000
# 2        0.001479  4.204642e-04         0.000000        0.000000
# 3        0.001515  5.918582e-04         0.000000        0.000000
# 4        0.000774  6.832793e-04         0.000000        0.000000
# 5        0.002948  1.631529e-03         0.000000        0.000000
# 6        0.001043  7.146235e-04         0.000000        0.000000
# 7        0.001078  1.242434e-03         0.000000        0.000000
# 8        0.001257  7.658999e-04         0.000000        0.000000
# 9        0.001129  6.354528e-04         0.000000        0.000000
# 10       0.001404  7.599521e-04         0.000000        0.000000
# 11       0.001289  1.179390e-03         0.000000        0.000000
# 12       0.000832  8.028661e-04         0.000000        0.000000
# 13       0.001420  9.539341e-04         0.000000        0.000000
# 14       0.051658  6.664511e-03         0.005095        0.001405
# 15       0.460477  1.048218e-01         0.022484        0.010844
# 16       0.067845  2.587186e-02         0.007127        0.006352
# 17       0.445768  9.309132e-02         0.016064        0.002892
# 18       0.001393  8.164692e-04         0.000000        0.000000
# 19       0.001934  1.451408e-03         0.000000        0.000000
# 20       0.124937  2.309815e-02         0.003061        0.001897
# 21       1.014001  9.496794e-02         0.010139        0.001744
# 22       0.105171  8.322723e-03         0.003122        0.002018
# 23       0.883559  3.677564e-01         0.010340        0.006426
# 24       0.002549  2.541825e-03         0.000000        0.000000
# 25       0.000615  7.538598e-04         0.000000        0.000000
# 26       0.046232  7.537151e-03         0.005130        0.003552
# 27       0.472821  7.557274e-02         0.024485        0.019165
# 28       0.053501  9.439326e-03         0.007768        0.004566
# 29       0.341900  2.156905e-02         0.013743        0.002927
# 30       0.000998  8.313940e-07         0.000000        0.000000
# 31       0.001059  7.165613e-04         0.000000        0.000000
# 32       0.050630  7.777818e-03         0.006693        0.005164
# 33       0.453607  6.831696e-02         0.016134        0.006904
# 34       0.039137  1.435450e-03         0.005023        0.002170
# 35       0.400782  7.525350e-02         0.013010        0.002306
#
#    param_criterion param_max_features  param_n_estimators  \
# 0              mse               auto                  10
# 1              mse               auto                 100
# 2              mse               sqrt                  10
# 3              mse               sqrt                 100
# 4              mse               log2                  10
# 5              mse               log2                 100
# 6              mae               auto                  10
# 7              mae               auto                 100
# 8              mae               sqrt                  10
# 9              mae               sqrt                 100
# 10             mae               log2                  10
# 11             mae               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18  absolute_error               auto                  10
# 19  absolute_error               auto                 100
# 20  absolute_error               sqrt                  10
# 21  absolute_error               sqrt                 100
# 22  absolute_error               log2                  10
# 23  absolute_error               log2                 100
# 24   squared_error               auto                  10
# 25   squared_error               auto                 100
# 26   squared_error               sqrt                  10
# 27   squared_error               sqrt                 100
# 28   squared_error               log2                  10
# 29   squared_error               log2                 100
# 30         poisson               auto                  10
# 31         poisson               auto                 100
# 32         poisson               sqrt                  10
# 33         poisson               sqrt                 100
# 34         poisson               log2                  10
# 35         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 1   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 4   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 5   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 6   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 7   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 10  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 11  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.822604
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.858205
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.848442
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.855429
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...           0.841580
# 21  {'criterion': 'absolute_error', 'max_features'...           0.856101
# 22  {'criterion': 'absolute_error', 'max_features'...           0.846591
# 23  {'criterion': 'absolute_error', 'max_features'...           0.855042
# 24  {'criterion': 'squared_error', 'max_features':...                NaN
# 25  {'criterion': 'squared_error', 'max_features':...                NaN
# 26  {'criterion': 'squared_error', 'max_features':...           0.835795
# 27  {'criterion': 'squared_error', 'max_features':...           0.859342
# 28  {'criterion': 'squared_error', 'max_features':...           0.849776
# 29  {'criterion': 'squared_error', 'max_features':...           0.852543
# 30  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 31  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.851433
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...           0.853379
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.829637
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.854033
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.762093           0.829972           0.810816
# 15           0.783248           0.847645           0.821493
# 16           0.766198           0.847617           0.794194
# 17           0.788657           0.844621           0.833546
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.774238           0.827971           0.809308
# 21           0.782872           0.849640           0.824546
# 22           0.791081           0.821802           0.808470
# 23           0.781733           0.843711           0.832693
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.772159           0.834313           0.801187
# 27           0.785464           0.844812           0.824241
# 28           0.780470           0.838098           0.794289
# 29           0.785852           0.845206           0.832449
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32           0.784735           0.831677           0.838608
# 33           0.787276           0.843626           0.833319
# 34           0.775995           0.835053           0.817173
# 35           0.792214           0.843336           0.826497
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2                 NaN              NaN             NaN               17
# 3                 NaN              NaN             NaN               17
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8                 NaN              NaN             NaN               17
# 9                 NaN              NaN             NaN               17
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.747082         0.794513        0.033505               16
# 15           0.766826         0.815484        0.035503                8
# 16           0.757320         0.802754        0.038920               10
# 17           0.771652         0.818781        0.032733                1
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.749348         0.800489        0.034135               12
# 21           0.775708         0.817773        0.033220                2
# 22           0.728825         0.799354        0.039651               13
# 23           0.769350         0.816506        0.034409                5
# 24                NaN              NaN             NaN               17
# 25                NaN              NaN             NaN               17
# 26           0.760635         0.800818        0.030924               11
# 27           0.766420         0.816056        0.035120                7
# 28           0.730543         0.798635        0.042797               14
# 29           0.768510         0.816912        0.033523                4
# 30                NaN              NaN             NaN               17
# 31                NaN              NaN             NaN               17
# 32           0.730497         0.807390        0.044564                9
# 33           0.769898         0.817500        0.032862                3
# 34           0.718014         0.795174        0.043780               15
# 35           0.764482         0.816112        0.033238                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
import pickle
filename="finalized_grid_RF_with_T&T.sav"
pickle.dump(grid, open(filename, 'wb'))

Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))

loaded_model = pickle.load(open("finalized_grid_RF_with_T&T.sav", 'rb'))
# Out:
# Future_Prediction=[45481.0078885]
# c:\Users\malathi.a\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
